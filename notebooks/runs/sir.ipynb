# %%
from ray.tune import Analysis

# %%
an = Analysis('/Users/dylanrandle/ray_results/gan_tuning_sir/')

# %%
an.dataframe('mean_squared_error', mode='min').sort_values(by='mean_squared_error').head(10)
# Out:
#       mean_squared_error  trial_id  training_iteration  time_this_iter_s  \
# 239             0.000242  8dd339a8                 176          0.298689
# 1564            0.000295  2e6504fa                 115          0.983470
# 1283            0.000357  2e239114                 199          0.365760
# 262             0.000385  402f9c66                 158          0.422897
# 713             0.000481  2e7029de                 140          0.382344
# 1764            0.000885  4040d49a                 194          0.249824
# 674             0.000886  8dce585c                 170          0.300334
# 341             0.000905  2e1bbce6                  58          0.908429
# 2227            0.000986  2e58cab4                 197          0.798454
# 1561            0.001086  8dd5c452                 118          0.227861
#
#        done  timesteps_total  episodes_total  \
# 239   False              NaN             NaN
# 1564  False              NaN             NaN
# 1283  False              NaN             NaN
# 262   False              NaN             NaN
# 713   False              NaN             NaN
# 1764  False              NaN             NaN
# 674   False              NaN             NaN
# 341   False              NaN             NaN
# 2227  False              NaN             NaN
# 1561  False              NaN             NaN
#
#                          experiment_id                 date   timestamp  ...  \
# 239   9eb197dc6d4c400bb2bbae6cde4da76c  2020-03-18_17-19-18  1584566358  ...
# 1564  1737448bec3c42fdae0a9770e5eff0b7  2020-03-18_18-32-13  1584570733  ...
# 1283  65050e3f8b0243fe9e203cd2e08b3bee  2020-03-18_18-03-08  1584568988  ...
# 262   144fabe9968647d1b329e2f2a0170190  2020-03-18_17-01-14  1584565274  ...
# 713   d6e6535ea0ce4b44a5afd5bf9f28500d  2020-03-18_18-35-29  1584570929  ...
# 1764  fa84d6ff98364c6ea5df5d839092eeeb  2020-03-18_17-05-03  1584565503  ...
# 674   f7a3b6c6201b48488e5e071d4a8d5a33  2020-03-18_17-17-55  1584566275  ...
# 341   929f2cccbc884c67b882263c6f84f98f  2020-03-18_17-59-30  1584568770  ...
# 2227  c6ba4506e14347cf8e33e1abe4edae5f  2020-03-18_18-27-30  1584570450  ...
# 1561  2ca3ab541575413188403fdd87de81e7  2020-03-18_17-19-56  1584566396  ...
#
#           node_ip  time_since_restore timesteps_since_restore  \
# 239   192.168.1.7           54.430376                       0
# 1564  192.168.1.7          110.478064                       0
# 1283  192.168.1.7           78.638443                       0
# 262   192.168.1.7           45.958327                       0
# 713   192.168.1.7           59.159955                       0
# 1764  192.168.1.7           50.402246                       0
# 674   192.168.1.7           55.136998                       0
# 341   192.168.1.7           54.121075                       0
# 2227  192.168.1.7          159.050368                       0
# 1561  192.168.1.7           34.677860                       0
#
#      iterations_since_restore  \
# 239                       177
# 1564                      116
# 1283                      200
# 262                       159
# 713                       141
# 1764                      195
# 674                       171
# 341                        59
# 2227                      198
# 1561                      119
#
#                                          experiment_tag  \
# 239                       36_d_lr=0.0016171,g_lr=0.0355
# 1564  202_n_hidden_layers=2,n_hidden_units=30,n_hidd...
# 1283  43_n_hidden_layers=3,n_hidden_units=20,n_hidde...
# 262                   23_d_lr=0.00068304,g_lr=0.0060696
# 713   228_n_hidden_layers=3,n_hidden_units=30,n_hidd...
# 1764                   64_d_lr=0.022253,g_lr=3.6588e-05
# 674                   21_d_lr=0.00011178,g_lr=0.0070428
# 341   22_n_hidden_layers=3,n_hidden_units=20,n_hidde...
# 2227  170_n_hidden_layers=3,n_hidden_units=20,n_hidd...
# 1561                   44_d_lr=0.0036273,g_lr=9.598e-05
#
#                                    config/discriminator  \
# 239   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 1564  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 1283  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 262   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 713   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 1764  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 674   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 341   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 2227  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 1561  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
#
#                                        config/generator  \
# 239   {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 1564  {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 1283  {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 262   {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 713   {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 1764  {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 674   {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 341   {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 2227  {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
# 1561  {'activation': 'Tanh', 'in_dim': 1, 'n_hidden_...
#
#                                          config/problem  \
# 239   {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 1564  {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 1283  {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 262   {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 713   {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 1764  {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 674   {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 341   {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 2227  {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
# 1561  {'I0': 0.3, 'R0': 0.0, 'S0': 0.7, 'beta': 1, '...
#
#                                         config/training  \
# 239   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 1564  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 1283  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 262   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 713   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 1764  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 674   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 341   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 2227  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 1561  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
#
#                                                  logdir
# 239   /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 1564  /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 1283  /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 262   /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 713   /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 1764  /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 674   /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 341   /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 2227  /Users/dylanrandle/ray_results/gan_tuning_sir/...
# 1561  /Users/dylanrandle/ray_results/gan_tuning_sir/...
#
# [10 rows x 23 columns]

# %%
an.get_best_config('mean_squared_error', mode='min')
# Out:
# {'discriminator': {'activation': 'Tanh',
#   'in_dim': 3,
#   'n_hidden_layers': 2,
#   'n_hidden_units': 20,
#   'out_dim': 1,
#   'regress': False,
#   'residual': True,
#   'spectral_norm': True},
#  'generator': {'activation': 'Tanh',
#   'in_dim': 1,
#   'n_hidden_layers': 2,
#   'n_hidden_units': 20,
#   'out_dim': 3,
#   'regress': True,
#   'residual': True},
#  'problem': {'I0': 0.3,
#   'R0': 0.0,
#   'S0': 0.7,
#   'beta': 1,
#   'gamma': 1,
#   'n': 100,
#   'perturb': True,
#   't_max': 10},
#  'training': {'D_iters': 1,
#   'G_iters': 1,
#   'conditional': False,
#   'd1': 1,
#   'd2': 1,
#   'd_betas': [0.9, 0.999],
#   'd_lr': 0.001617053921830959,
#   'dirname': 'SIR_run',
#   'g_betas': [0.9, 0.999],
#   'g_lr': 0.03549958414548462,
#   'gamma': 0.999,
#   'gp': 0.1,
#   'log': False,
#   'loss_fn': 'MSELoss',
#   'lr_schedule': False,
#   'method': 'unsupervised',
#   'niters': 2000,
#   'obs_every': 1,
#   'plot': False,
#   'save': False,
#   'seed': 0,
#   'wgan': False}}
