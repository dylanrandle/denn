# %%
from ray.tune import Analysis

# %%
an = Analysis('/Users/dylanrandle/Downloads/gan_tuning_sir')

# %%
df = an.dataframe('mean_squared_error', mode='min').sort_values(by='mean_squared_error')
df.shape
# Out:
# (3000, 23)

# %%
df.head(5)
# Out:
#       mean_squared_error  trial_id  training_iteration  time_this_iter_s  \
# 2994        4.703231e-09       111                 998          0.748211
# 2199        7.699422e-09       213                 851          2.129852
# 2191        1.420482e-08       867                 466          2.232066
# 617         2.980960e-08       550                 981          0.955641
# 173         4.081804e-08       966                 999          0.494620
#
#        done  timesteps_total  episodes_total  \
# 2994  False              NaN             NaN
# 2199  False              NaN             NaN
# 2191  False              NaN             NaN
# 617   False              NaN             NaN
# 173   False              NaN             NaN
#
#                          experiment_id                 date   timestamp  ...  \
# 2994  299145a20116427893bef38b6efc557b  2020-05-24_14-53-12  1590331992  ...
# 2199  e7298813ed1a4b04aec3815cccbc5a14  2020-05-22_17-32-33  1590168753  ...
# 2191  264a28e247d64622a4c847da3221a404  2020-05-24_15-56-53  1590335813  ...
# 617   0bda140192574ac0bd2c00d0f4eef195  2020-05-24_15-34-13  1590334453  ...
# 173   f125e47724284b29a79e1b389a68c0c0  2020-05-24_16-07-11  1590336431  ...
#
#             node_ip  time_since_restore timesteps_since_restore  \
# 2994  172.31.82.237          939.636440                       0
# 2199  172.31.82.237          932.446472                       0
# 2191  172.31.82.237          662.846770                       0
# 617   172.31.82.237         1008.075113                       0
# 173   172.31.82.237          762.845227                       0
#
#      iterations_since_restore  \
# 2994                      999
# 2199                      852
# 2191                      467
# 617                       982
# 173                      1000
#
#                                          experiment_tag  \
# 2994  111_n_hidden_layers=3,n_hidden_units=20,n_hidd...
# 2199  213_n_hidden_layers=4,n_hidden_units=20,n_hidd...
# 2191  867_n_hidden_layers=6,n_hidden_units=40,n_hidd...
# 617   550_n_hidden_layers=2,n_hidden_units=30,n_hidd...
# 173   966_n_hidden_layers=4,n_hidden_units=30,n_hidd...
#
#                                    config/discriminator  \
# 2994  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 2199  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 2191  {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 617   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
# 173   {'activation': 'Tanh', 'in_dim': 3, 'n_hidden_...
#
#                                        config/generator  \
# 2994  {'in_dim': 1, 'n_hidden_layers': 2, 'n_hidden_...
# 2199  {'in_dim': 1, 'n_hidden_layers': 3, 'n_hidden_...
# 2191  {'in_dim': 1, 'n_hidden_layers': 5, 'n_hidden_...
# 617   {'in_dim': 1, 'n_hidden_layers': 3, 'n_hidden_...
# 173   {'in_dim': 1, 'n_hidden_layers': 4, 'n_hidden_...
#
#                                          config/problem  \
# 2994  {'I0': 0.01, 'R0': 0.0, 'S0': 0.99, 'beta': 3,...
# 2199  {'I0': 0.01, 'R0': 0.0, 'S0': 0.99, 'beta': 3,...
# 2191  {'I0': 0.01, 'R0': 0.0, 'S0': 0.99, 'beta': 3,...
# 617   {'I0': 0.01, 'R0': 0.0, 'S0': 0.99, 'beta': 3,...
# 173   {'I0': 0.01, 'R0': 0.0, 'S0': 0.99, 'beta': 3,...
#
#                                         config/training  \
# 2994  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 2199  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 2191  {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 617   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
# 173   {'D_iters': 1, 'G_iters': 1, 'conditional': Fa...
#
#                                                  logdir
# 2994  /Users/dylanrandle/Downloads/gan_tuning_sir/ga...
# 2199  /Users/dylanrandle/Downloads/gan_tuning_sir/ga...
# 2191  /Users/dylanrandle/Downloads/gan_tuning_sir/ga...
# 617   /Users/dylanrandle/Downloads/gan_tuning_sir/ga...
# 173   /Users/dylanrandle/Downloads/gan_tuning_sir/ga...
#
# [5 rows x 23 columns]

# %%
an.get_best_config('mean_squared_error', mode='min')
# Out:
# {'discriminator': {'activation': 'Tanh',
#   'in_dim': 3,
#   'n_hidden_layers': 3,
#   'n_hidden_units': 20,
#   'out_dim': 1,
#   'regress': False,
#   'residual': True,
#   'spectral_norm': True},
#  'generator': {'in_dim': 1,
#   'n_hidden_layers': 2,
#   'n_hidden_units': 40,
#   'out_dim': 3,
#   'regress': True,
#   'residual': True},
#  'problem': {'I0': 0.01,
#   'R0': 0.0,
#   'S0': 0.99,
#   'beta': 3,
#   'gamma': 1,
#   'n': 800,
#   'perturb': True,
#   't_max': 10},
#  'training': {'D_iters': 1,
#   'G_iters': 1,
#   'conditional': False,
#   'd1': 1,
#   'd2': 1,
#   'd_betas': '[0.19268249 0.61740443]',
#   'd_lr': 0.002177634209548115,
#   'dirname': 'SIR_run_gan_052220',
#   'g_betas': '[0.20705222 0.16897627]',
#   'g_lr': 0.009949364998471707,
#   'gamma': 0.999227612781647,
#   'gp': 0.1,
#   'log': False,
#   'loss_fn': 'MSELoss',
#   'lr_schedule': True,
#   'method': 'unsupervised',
#   'niters': 10000,
#   'obs_every': 1,
#   'plot': False,
#   'save': False,
#   'save_for_animation': False,
#   'seed': 0,
#   'wgan': False}}

# %% [markdown]
# # RK4

# %%
import sys
sys.path.append('../../')

from denn.rk4 import rk4
import numpy as np
import matplotlib.pyplot as plt

# %%
def sir_deriv(t, sir):
    """ 
    dxdt = z
    dzdt = -x
    """
    S, I, R = sir[0], sir[1], sir[2]
    
    beta = 3 
    N = 1
    gamma = 1
    
    rhs1 = -beta*I*S/N
    rhs2 = (beta*I*S/N) - gamma*I
    rhs3 = gamma*I
    return np.array([rhs1, rhs2, rhs3])
    return rhs

# %%
t, sol = rk4(sir_deriv, [0, 10], [0.99, 0.01, 0.00], 800)

# %%
from denn.ode_problems import SIRModel
sir_sol = SIRModel(S0=0.99, I0=0.01, R0=0.00, beta=3, gamma=1, n=800).get_solution(t)

# %%
sol.shape, sir_sol.shape
# Out:
# ((801, 3), torch.Size([801, 3]))

# %%
((sol-sir_sol.numpy())**2).shape
# Out:
# (801, 3)

# %%
mse = np.mean( (sol - sir_sol.numpy())**2 )

# %%
mse
# Out:
# 5.731306e-13

# %% [markdown]
# # Model inits are fixed, data randomized

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../')
import denn.utils as ut

# %%
# folder = lambda i: f"/Users/dylanrandle/Downloads/SIR_run_gan_052520_seed{i}/val_mse.npy"
# gan_reps = []
# for i in range(5):
#     gan_reps.append(np.load(folder(i)))
# gan_reps = np.vstack(gan_reps)

# %%
gan_reps = np.load('C:/Users/Blake Bullwinkel/Documents/Harvard/denn/experiments/reps/sir/sir_rand_reps_gan.npy')
kept_runs = [0,2,3,5,7]
gan_reps = gan_reps[kept_runs, :]

l2_reps = np.load('C:/Users/Blake Bullwinkel/Documents/Harvard/denn/experiments/reps/sir/sir_rand_reps_L2.npy')
#l2_reps = np.load('/Users/dylanrandle/Downloads/sir_reps_052520_mse.npy')

l1_reps = np.load('C:/Users/Blake Bullwinkel/Documents/Harvard/denn/experiments/reps/sir/sir_rand_reps_L1.npy')
#l1_reps = np.load('/Users/dylanrandle/Downloads/sir_reps_052520_l1.npy')

huber_reps = np.load('C:/Users/Blake Bullwinkel/Documents/Harvard/denn/experiments/reps/sir/sir_rand_reps_huber.npy')
#huber_reps = np.load('/Users/dylanrandle/Downloads/sir_reps_052520_huber.npy')

# %%
arrs_dict = {"GAN": gan_reps[:,:20000], 
             "$L_2$": l2_reps[:,:20000],
             "$L_1$": l1_reps[:,:20000], 
             "Huber": huber_reps,
#              "RK4": mse*np.ones_like(huber_reps)
            }
ut.plot_reps_results(arrs_dict, fname="sir_rand_reps.png", 
                     window=50, figsize=(10,6), pctiles=(25,75), linewidth=4)

# %%
print(f"L1 Min: {np.min(l1_reps)}")
print(f"L2 Min: {np.min(l2_reps)}")
print(f"Huber Min: {np.min(huber_reps)}")
print(f"GAN Min: {np.min(gan_reps)}")
# Out:
# L1 Min: 7.55260480218567e-05
# L2 Min: 3.3091749340741217e-09
# Huber Min: 1.836853780190495e-09
# GAN Min: 1.597298127098412e-10

# %% [markdown]
# # With classical tuned

# %%
l2_reps_tuned = np.load('../../experiments/reps/sir_l2_rand_reps_classical_tuned.npy')
l1_reps_tuned = np.load('../../experiments/reps/sir_l1_rand_reps_classical_tuned.npy')
huber_reps_tuned = np.load('../../experiments/reps/sir_huber_rand_reps_classical_tuned.npy')

# %%
arrs_dict = {"GAN": gan_reps, 
             "$L_2$": l2_reps,
             "$L_2$-tuned": l2_reps_tuned,
             "$L_1$": l1_reps, 
             "$L_1$-tuned": l1_reps_tuned,
             "Huber": huber_reps,
             "Huber-tuned": huber_reps_tuned}
ut.plot_reps_results(arrs_dict, fname="sir_rand_reps_classic_tune.png", figsize=(10,6), window=50)

# %% [markdown]
# # Population conservation
#
# $$ S(t) + I(t) + R(t) = N $$

# %%
import denn.utils

# %%
snum = np.load('../../experiments/runs/SIR_run_March20_gan/$S$_pred.npy')
inum = np.load('../../experiments/runs/SIR_run_March20_gan/$I$_pred.npy')
rnum = np.load('../../experiments/runs/SIR_run_March20_gan/$R$_pred.npy')

# %%
snum.shape
# Out:
# (200,)

# %%
numsum = snum + inum + rnum

# %%
numsum.shape
# Out:
# (200,)

# %%
spred = np.load('../../experiments/runs/SIR_run_March20_gan/$\hat{S}$_pred.npy')
ipred = np.load('../../experiments/runs/SIR_run_March20_gan/$\hat{I}$_pred.npy')
rpred = np.load('../../experiments/runs/SIR_run_March20_gan/$\hat{R}$_pred.npy')

# %%
predsum = spred + ipred + rpred

# %%
sl2 = np.load('../../experiments/runs/SIR_run_March20_l2/$\hat{S}$_pred.npy')
il2 = np.load('../../experiments/runs/SIR_run_March20_l2/$\hat{I}$_pred.npy')
rl2 = np.load('../../experiments/runs/SIR_run_March20_l2/$\hat{R}$_pred.npy')

# %%
sl1 = np.load('../../experiments/runs/SIR_run_March20_l1/$\hat{S}$_pred.npy')
il1 = np.load('../../experiments/runs/SIR_run_March20_l1/$\hat{I}$_pred.npy')
rl1 = np.load('../../experiments/runs/SIR_run_March20_l1/$\hat{R}$_pred.npy')

# %%
shu = np.load('../../experiments/runs/SIR_run_March20_smoothl1/$\hat{S}$_pred.npy')
ihu = np.load('../../experiments/runs/SIR_run_March20_smoothl1/$\hat{I}$_pred.npy')
rhu = np.load('../../experiments/runs/SIR_run_March20_smoothl1/$\hat{R}$_pred.npy')

# %%
plt.figure(figsize=(10,6))
t = np.linspace(0, 10, 200)
plt.plot(t, numsum, label='RK4', color='blue', linestyle='dotted')
plt.plot(t, predsum, label='GAN', color='crimson')
plt.plot(t, sl2+il2+rl2, label='$L_2$', color='limegreen', linestyle='solid')
plt.plot(t, sl1+il1+rl1, label='$L_1$', color='aquamarine', linestyle='dashdot')
plt.plot(t, shu+ihu+rhu, label='Huber', color='violet', linestyle='dashed')
plt.xlabel('Time ($t$)')
plt.ylabel('Population ($N$)')
plt.legend(loc='lower right')
plt.grid()
plt.ylim([0.96, 1.01]);

# %%
from denn.problems import SIRModel
sir = SIRModel(n=200, S0=0.99, I0=0.01, R0=0.0, beta=3, gamma=1)

# %%
from scipy.integrate import odeint
init_cond = [sir.S0, sir.I0, sir.R0]
t = sir.grid.detach().flatten()
sol = odeint(sir._sir_system, init_cond, t, tfirst=True)

# %%
from scipy.integrate import solve_ivp
sol_ivp = solve_ivp(sir._sir_system, (0, 10), init_cond, t_eval=t)

# %%
sol_ivp.y.shape
# Out:
# (3, 200)

# %%
t = np.linspace(0, 10, 200)
plt.plot(t, numsum, label='SP')
plt.plot(t, predsum, label='NN')
plt.plot(t, np.sum(sol_ivp.y, axis=0), label='RK4')
plt.legend()
plt.yscale('log')

# %% [markdown]
# # Non-collapse initial conditions

# %%
snum = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$S$_pred.npy')
inum = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$I$_pred.npy')
rnum = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$R$_pred.npy')

# %%
spred = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$\hat{S}$_pred.npy')
ipred = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$\hat{I}$_pred.npy')
rpred = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_gan/$\hat{R}$_pred.npy')

# %%
sl2 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L2/$\hat{S}$_pred.npy')
il2 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L2/$\hat{I}$_pred.npy')
rl2 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L2/$\hat{R}$_pred.npy')

# %%
sl1 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L1/$\hat{S}$_pred.npy')
il1 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L1/$\hat{I}$_pred.npy')
rl1 = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_L1/$\hat{R}$_pred.npy')

# %%
shu = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_smoothL1/$\hat{S}$_pred.npy')
ihu = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_smoothL1/$\hat{I}$_pred.npy')
rhu = np.load('../../experiments/runs/SIR_run_March22_noncollapse_energy_smoothL1/$\hat{R}$_pred.npy')

# %%
plt.figure(figsize=(10,6))
t = np.linspace(0, 10, 200)
alpha=0.8
plt.plot(t, snum+inum+rnum, label='RK4', color='black', linestyle='dotted', alpha=alpha)
plt.plot(t, spred+ipred+rpred, label='GAN', color='crimson', alpha=alpha)
plt.plot(t, sl2+il2+rl2, label='$L_2$', color='violet', linestyle='solid', alpha=alpha)
plt.plot(t, sl1+il1+rl1, label='$L_1$', color='limegreen', linestyle='dashdot', alpha=alpha)
plt.plot(t, shu+ihu+rhu, label='Huber', color='blue', linestyle='dashed', alpha=alpha)
plt.xlabel('Time ($t$)')
plt.ylabel('Population ($N$)')
plt.legend(loc='lower right')
plt.grid()
plt.ylim([0.985, 1.005]);

# %%
plt.figure(figsize=(10,6))
t = np.linspace(0, 10, 200)
alpha=0.8
# plt.plot(t, snum+inum+rnum, label='RK4', color='black', linestyle='dotted', alpha=alpha)
# plt.plot(t, spred+ipred+rpred, label='GAN', color='crimson', alpha=alpha)
# plt.plot(t, sl2+il2+rl2, label='$L_2$', color='violet', linestyle='solid', alpha=alpha)
# plt.plot(t, sl1+il1+rl1, label='$L_1$', color='limegreen', linestyle='dashdot', alpha=alpha)
# plt.plot(t, shu+ihu+rhu, label='Huber', color='blue', linestyle='dashed', alpha=alpha)
plt.plot(t, (sl2+il2+rl2) - (shu+ihu+rhu), label='L2 - Huber')
plt.yscale('log')
plt.xlabel('Time ($t$)')
plt.ylabel('Population ($N$)')
plt.legend(loc='lower right')
plt.grid()
# plt.ylim([0.985, 1.005]);

# %% [markdown]
# # Euler Method to compare

# %%
init_cond = [sir.S0, sir.I0, sir.R0]
t = sir.grid.detach().numpy().flatten()

# %%
def euler( x0, y, h, x, func ): 
    temp = -0
  
    # Iterating till the point at which we 
    # need approximation 
    while x0 < x: 
        temp = y 
        y = y + h * func(x0, y) 
        x0 = x0 + h 
        
    return y

# %%
h = float((t[1] - t[0]))
h
# Out:
# 0.05025125667452812

# %%
yeul = []
init_cond = [0.7, 0.3, 0.0]
for p in t:
    yeu = euler(0, init_cond, h, p, sir._sir_system) 
    yeul.append(yeu)
yeul = np.vstack(yeul)

# %%
plt.plot(t, yeul[:,0])
plt.plot(t, yeul[:,1])
plt.plot(t, yeul[:,2]);

# %%
plt.figure(figsize=(10,6))
t = np.linspace(0, 10, 200)
alpha=0.8
plt.plot(t, snum+inum+rnum, label='RK4', color='black', linestyle='dotted', alpha=alpha)
plt.plot(t, spred+ipred+rpred, label='GAN', color='crimson', alpha=alpha)
plt.plot(t, np.sum(yeul, axis=1), label='euler', color='orange', alpha=alpha)
plt.plot(t, sl2+il2+rl2, label='$L_2$', color='violet', linestyle='solid', alpha=alpha)
plt.plot(t, sl1+il1+rl1, label='$L_1$', color='limegreen', linestyle='dashdot', alpha=alpha)
plt.plot(t, shu+ihu+rhu, label='Huber', color='blue', linestyle='dashed', alpha=alpha)
plt.xlabel('Time ($t$)')
plt.ylabel('Population ($N$)')
plt.legend(loc='lower right')
plt.grid()
plt.ylim([0.985, 1.005]);
