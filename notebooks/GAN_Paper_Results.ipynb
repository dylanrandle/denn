# %%
from denn.sho.gan_sho import train_GAN_SHO
import torch.nn as nn

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1
#
# LR schedule

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 1
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 2

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=2,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 4

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 5

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# No LR sched

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=5000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# LR Sched 25K

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=25000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# Lr Sched 50K

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2= 1.
#
# Softplus

# %%
res = train_GAN_SHO(
    activation=nn.Softplus(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x5, 20x5
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    activation=nn.Tanh(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=5,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# **API CHANGE: specify d2 units/layers**

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = 1., d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_units=30,
    d_hidden_layers=10,
    d2_units=20,
    d2_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# Equilibrium GAN

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_units=30,
    d_hidden_layers=3,
    d2_units=30,
    d2_layers=3,
    eq=True,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000,
    realtime_plot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-09b0f70031dc> in <module>
#      21     decay_start_epoch=50000,
#      22     check_every=1000,
# ---> 23     realtime_plot=True)
#
# ~/Documents/harvard/research/denn/denn/sho/gan_sho.py in train_GAN_SHO(num_epochs, activation, g_hidden_units, d_hidden_units, g_hidden_layers, d_hidden_layers, d_lr, g_lr, d_betas, g_betas, G_iters, D_iters, d2_units, d2_layers, start_d2, eq, eq_k, eq_lr, t_low, t_high, x0, dx_dt0, n, m, k, real_label, fake_label, perturb, residual, observe_every, wgan, gp, d1, d2, outputTan, systemOfODE, conditionalGAN, lr_schedule, decay_start_epoch, savefig, fname, device, check_every, logging, realtime_plot, seed)
#     231             # Below: trying MSE loss
#     232             # g_loss = d1 * mse_loss(fake, real) + d2_hyper * criterion(D2(fake2), real_label_vec)
# --> 233             g_loss.backward(retain_graph=True)
#     234             optiG.step()
#     235
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %% [markdown]
# # Lagaris

# %%
from denn.sho.mse_sho import train_MSE
from denn.utils import Generator

# %% [markdown]
# Semi-sup

# %%
resgnet = Generator(n_hidden_units=30, n_hidden_layers=5, residual=True)
train_MSE(resgnet, niters=100000)

# %% [markdown]
# Sup

# %%
resgnet = Generator(n_hidden_units=30, n_hidden_layers=5, residual=True)
train_MSE(resgnet, method='supervised', niters=100000)
