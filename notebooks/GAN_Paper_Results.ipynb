# %%
from denn.sho.gan_sho import train_GAN_SHO
import torch.nn as nn

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1
#
# LR schedule

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 1
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 2

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=2,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 4

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 5

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# No LR sched

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=5000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# LR Sched 25K

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=25000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# Lr Sched 50K

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2= 1.
#
# Softplus

# %%
res = train_GAN_SHO(
    activation=nn.Softplus(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x5, 20x5
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    activation=nn.Tanh(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=5,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# **API CHANGE: specify d2 units/layers**

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = 1., d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_units=30,
    d_hidden_layers=10,
    d2_units=20,
    d2_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# Equilibrium GAN
#
# (real anchor)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_units=30,
    d_hidden_layers=3,
    d2_units=30,
    d2_layers=3,
    eq=True,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# fake anchor

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_units=30,
    d_hidden_layers=3,
    d2_units=30,
    d2_layers=3,
    eq=True,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=4,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=10.,
    realtime_plot=True
)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=10.,
    realtime_plot=True
)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=100.,
    realtime_plot=True
)

# %% [markdown]
# # Results from Big Hyper Job

# %%
res = train_GAN_SHO(num_epochs=10000, seed=0, 
                    **{'g_units': 32, 'g_layers': 4, 'd_units': 32, 'd_layers': 8, 'd2_units': 16, 'd2_layers': 8, 'd2': 0.1},
                   realtime_plot=True)

# %% [markdown]
# # Results from Hyperjob 2

# %%
res = train_GAN_SHO(realtime_plot=True)

# %%
res = train_GAN_SHO(realtime_plot=True, d1=1e-3, d2=1)

# %% [markdown]
# # MSE for Unsupervised Loss: "Phys Loss"

# %%
from denn.sho.gan_sho import train_GAN_SHO
import torch.nn as nn

# %%
res = train_GAN_SHO(realtime_plot=True, d1=1, d2=1, observe_every=1, num_epochs=100000)

# %%
res['final_mse']
# Out:
# 9.926106940838508e-06

# %% [markdown]
# # After hypertune

# %%
opt_params = {'d_lr': 0.001, 'g_lr': 0.001, 'g_units': 64, 'g_layers': 8, 'd_units': 32, 'd_layers': 8}
res = train_GAN_SHO(**opt_params, realtime_plot=True, d1=1, d2=1, observe_every=1, num_epochs=10000)
res['final_mse']
# Out:
# 1.0405685316072777e-05

# %%
opt_params = {'d_lr': 0.001, 'g_lr': 0.001, 'g_units': 64, 'g_layers': 8, 'd_units': 32, 'd_layers': 8}
res = train_GAN_SHO(**opt_params, realtime_plot=True, d1=1, d2=1, observe_every=1, num_epochs=100000)

# %%
res['final_mse']
# Out:
# 9.674975444795564e-06

# %% [markdown]
# Timing 10K epochs

# %%
# %%time
res = train_GAN_SHO(realtime_plot=False, observe_every=1, num_epochs=10000)
# Out:
# CPU times: user 1h 22min 24s, sys: 1min 43s, total: 1h 24min 8s
# Wall time: 8min 21s

# %% [markdown]
# # Observers every 4

# %%
res = train_GAN_SHO(realtime_plot=True, d1=1, d2=1, observe_every=4, num_epochs=100000)

# %%
res['final_mse']
# Out:
# 1.0202310477325227e-05

# %% [markdown]
# # Observers every 10

# %%
res = train_GAN_SHO(realtime_plot=True, d1=1, d2=1, observe_every=10, num_epochs=100000)

# %%
res['final_mse']
# Out:
# 1.8903279851656407e-05

# %%
res = train_GAN_SHO(realtime_plot=True, observe_every=10, num_epochs=10000)
res['final_mse']
# Out:
# 1.9637576770037413e-05

# %% [markdown]
# # Lagaris

# %%
from denn.sho.mse_sho import train_MSE
from denn.utils import Generator

# %% [markdown]
# # Semi-sup

# %%
# %%time
resgnet = Generator(n_hidden_units=64, n_hidden_layers=8, residual=True)
res = train_MSE(resgnet, make_plot=True, method='semisupervised', niters=10000)
res['final_mse']
# Out:
# CPU times: user 52min 14s, sys: 1min 20s, total: 53min 35s
# Wall time: 5min 24s
# 0.002112400019541383

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='semisupervised', niters=100000)

# %%
res['final_mse']
# Out:
# 0.00011669446394080296

# %% [markdown]
# # Observers every 4

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='semisupervised', niters=100000, observe_every=4)

# %%
res['final_mse']
# Out:
# 0.000116341543616727

# %% [markdown]
# # Observers every 10

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='semisupervised', niters=100000, observe_every=10)

# %%
res['final_mse']
# Out:
# 0.00020390431745909154

# %% [markdown]
# # Un-sup

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='unsupervised', niters=100000)

# %%
res['final_mse']
# Out:
# 0.007877404801547527

# %%
resgnet = Generator(n_hidden_units=64, n_hidden_layers=8, residual=True)
res = train_MSE(resgnet, method='unsupervised', niters=10000, seed=0)
res['final_mse']

# %% [markdown]
# # Sup

# %%
# %%time
resgnet = Generator(n_hidden_units=64, n_hidden_layers=8, residual=True)
res = train_MSE(resgnet, method='supervised', niters=10000, make_plot=True)
res['final_mse']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/harvard/research/denn/denn/sho/mse_sho.py in train_MSE(model, method, niters, x0, dx_dt0, seed, n, tmax, perturb, lr, betas, observe_every, d1, d2, make_plot)
#      58             loss_trace.append(loss.item())
#      59
# ---> 60         loss.backward(retain_graph=True)
#      61         opt.step()
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
# ...

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='supervised', niters=100000)

# %%
res['final_mse']
# Out:
# 0.00010310902143828571

# %% [markdown]
# Observers every 10

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
res = train_MSE(resgnet, method='supervised', niters=100000, observe_every=10)

# %%
res['final_mse']
# Out:
# 0.016976477578282356

# %% [markdown]
# # Varying obs_every

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('axes', titlesize=15, labelsize=12)
plt.rc('legend', fontsize=12)

# %%
lag = pd.read_csv('~/Downloads/LAG_obsevery_mse_results.csv', index_col=0)

# %%
gan = pd.read_csv('/Users/dylanrandle/Downloads/GAN_obsevery_mse_results.csv', index_col=0)

# %%
lag['mses'] = lag.mses.apply(lambda x: np.array([float(i) for i in x.strip('][').split(', ')]))
gan['mses'] = gan.mses.apply(lambda x: np.array([float(i) for i in x.strip('][').split(', ')]))

# %%
lag = lag.sort_values(by='obs_every')
gan = gan.sort_values(by='obs_every')

# %%
plt.figure(figsize=(10,6))
plt.errorbar(lag.obs_every, [np.mean(mse[:3]) for mse in lag.mses], [np.std(mse[:3]) for mse in lag.mses], label='MSE')
plt.errorbar(gan.obs_every, [np.mean(mse) for mse in gan.mses], [np.std(mse) for mse in gan.mses], label='GAN')
plt.yscale('log')
plt.xlabel('Observer Gap')
plt.ylabel('Mean Square Error')
plt.legend()
