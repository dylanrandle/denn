# %%
from denn.sho.gan_sho import train_GAN_SHO
import torch.nn as nn

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x7, 30x3, 30x3
#
# d1 = 1, d2 = .1
#
# LR schedule

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=5000,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 1
#
# d1 = 1, d2 = .1

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Observers every 2

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=2,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 4

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# Obs every 5

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=4,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=.1,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# No LR sched

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=False,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=5000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# LR Sched 25K

# %%
res = train_GAN_SHO(
    num_epochs=50000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=25000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# Lr Sched 50K

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x10, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=10,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x3, 20x3
#
# d1 = .1, d2= 1.
#
# Softplus

# %%
res = train_GAN_SHO(
    activation=nn.Softplus(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=3,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x5, 20x5
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    activation=nn.Tanh(),
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=20,
    g_hidden_layers=20,
    d_hidden_layers=5,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = .1, d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    d_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=.1,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# **API CHANGE: specify d2 units/layers**

# %% [markdown]
# 30x20, 20x10, 20x10
#
# d1 = 1., d2 = 1.

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=20,
    d_hidden_units=30,
    d_hidden_layers=10,
    d2_units=20,
    d2_layers=10,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=50000,
    check_every=1000)

# %% [markdown]
# Equilibrium GAN
#
# (real anchor)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_units=30,
    d_hidden_layers=3,
    d2_units=30,
    d2_layers=3,
    eq=True,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %% [markdown]
# fake anchor

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    g_hidden_units=30,
    g_hidden_layers=7,
    d_hidden_units=30,
    d_hidden_layers=3,
    d2_units=30,
    d2_layers=3,
    eq=True,
    d_lr=0.0002,
    g_lr=0.0002,
    d_betas=(0.0, 0.9),
    g_betas=(0.0, 0.9),
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    wgan=True,
    d1=1.,
    d2=1.,
    decay_start_epoch=0,
    check_every=1000,
    realtime_plot=True)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=4,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=10.,
    realtime_plot=True
)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=10.,
    realtime_plot=True
)

# %%
res = train_GAN_SHO(
    num_epochs=100000,
    
    g_hidden_units=30,
    g_hidden_layers=3,
    
    d_hidden_units=30,
    d_hidden_layers=3,
    
    d2_units=30,
    d2_layers=3,
    eq=True,
    
    G_iters=1,
    D_iters=1,
    observe_every=1,
    lr_schedule=True,
    decay_start_epoch=0,
    d1=1.,
    d2=100.,
    realtime_plot=True
)

# %% [markdown]
# # Results from Big Hyper Job

# %%
res = train_GAN_SHO(num_epochs=10000, seed=0, 
                    **{'g_units': 32, 'g_layers': 4, 'd_units': 32, 'd_layers': 8, 'd2_units': 16, 'd2_layers': 8, 'd2': 0.1},
                   realtime_plot=True)

# %% [markdown]
# # Results from Hyperjob 2

# %%
res = train_GAN_SHO(realtime_plot=True)

# %%
res = train_GAN_SHO(realtime_plot=True, d1=1e-3, d2=1)

# %% [markdown]
# # MSE for Unsupervised Loss: "Phys Loss"

# %%
# mse on eqn loss
res = train_GAN_SHO(realtime_plot=True, d1=1, d2=1, observe_every=1)

# %%
res
# Out:
# {'final_mse': 1.0088672752317507e-05}

# %% [markdown]
# # Lagaris (Semi-Supervised)

# %%
from denn.sho.mse_sho import train_MSE
from denn.utils import Generator

# %% [markdown]
# Semi-sup

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
train_MSE(resgnet, method='semisupervised', niters=50000);

# %% [markdown]
# Un-sup

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
train_MSE(resgnet, method='unsupervised', niters=50000);

# %% [markdown]
# Sup

# %%
resgnet = Generator(n_hidden_units=32, n_hidden_layers=4, residual=True)
train_MSE(resgnet, method='supervised', niters=50000);

# %% [markdown]
# # Varying obs_every

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('axes', titlesize=15, labelsize=12)
plt.rc('legend', fontsize=12)

# %%
lag = pd.read_csv('~/Downloads/LAG_obsevery_mse_results.csv', index_col=0)

# %%
gan = pd.read_csv('/Users/dylanrandle/Downloads/GAN_obsevery_mse_results.csv', index_col=0)

# %%
lag['mses'] = lag.mses.apply(lambda x: np.array([float(i) for i in x.strip('][').split(', ')]))
gan['mses'] = gan.mses.apply(lambda x: np.array([float(i) for i in x.strip('][').split(', ')]))

# %%
lag = lag.sort_values(by='obs_every')
gan = gan.sort_values(by='obs_every')

# %%
plt.figure(figsize=(10,6))
plt.errorbar(lag.obs_every, [np.mean(mse[:3]) for mse in lag.mses], [np.std(mse[:3]) for mse in lag.mses], label='MSE')
plt.errorbar(gan.obs_every, [np.mean(mse) for mse in gan.mses], [np.std(mse) for mse in gan.mses], label='GAN')
plt.yscale('log')
plt.xlabel('Observer Gap')
plt.ylabel('Mean Square Error')
plt.legend()
