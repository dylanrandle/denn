# %%
from denn.utils import plot_results

# %%
import numpy as np

# %%
nlo_dir = "/Users/dylanrandle/Downloads/NLO_run_gan_053020_seed1/"

mses = {"train": np.load(nlo_dir+"train_mse.npy"), "val": np.load(nlo_dir+"val_mse.npy")}

loss_dict = {"G": np.load(nlo_dir+"G_loss.npy"), "D": np.load(nlo_dir+"D_loss.npy")}

grid = np.load(nlo_dir+"grid.npy")

pred_dict = {"$\hat{x}$": np.load(nlo_dir+"$\hat{x}$_pred.npy"), "$x$": np.load(nlo_dir+"$x$_pred.npy")}

diff_dict = {"$|\hat{F}|$": np.load(nlo_dir+"$|\hat{F}|$_diff.npy")}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=nlo_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/NLO_run_gan_053020_seed1/

# %%
sir_dir = "/Users/dylanrandle/Downloads/SIR_run_gan_053020_seed0/"

mses = {"train": np.load(sir_dir+"train_mse.npy"), "val": np.load(sir_dir+"val_mse.npy")}

loss_dict = {"G": np.load(sir_dir+"G_loss.npy"), "D": np.load(sir_dir+"D_loss.npy")}

grid = np.load(sir_dir+"grid.npy")

pred_dict = {
    "$\hat{S}$": np.load(sir_dir+"$\hat{S}$_pred.npy"),
    "$\hat{I}$": np.load(sir_dir+"$\hat{I}$_pred.npy"),
    "$\hat{R}$": np.load(sir_dir+"$\hat{R}$_pred.npy"),
    "$S$": np.load(sir_dir+"$S$_pred.npy"),
    "$I$": np.load(sir_dir+"$I$_pred.npy"),
    "$R$": np.load(sir_dir+"$R$_pred.npy"),
}

diff_dict = {
    "$|\hat{F_1}|$": np.load(sir_dir+"$|\hat{F_1}|$_diff.npy"),
    "$|\hat{F_2}|$": np.load(sir_dir+"$|\hat{F_2}|$_diff.npy"),
    "$|\hat{F_3}|$": np.load(sir_dir+"$|\hat{F_3}|$_diff.npy"),
}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=sir_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/SIR_run_gan_053020_seed0/

# %%
the_dir = "/Users/dylanrandle/Downloads/POS_run_gan_053020_seed0/"

mses = {"train": np.load(the_dir+"train_mse.npy"), "val": np.load(the_dir+"val_mse.npy")}

loss_dict = {"G": np.load(the_dir+"G_loss.npy"), "D": np.load(the_dir+"D_loss.npy")}

grid = np.load(the_dir+"grid.npy")

pred_dict = {
    "$\hat{u}$": np.load(the_dir+"$\hat{u}$_pred.npy"),
}

diff_dict = {
    "$|\hat{F}|$": np.load(the_dir+"$|\hat{F}|$_diff.npy"),
}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=the_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/POS_run_gan_053020_seed0/

# %%
the_dir = "/Users/dylanrandle/Downloads/COO_run_gan_besthype_052220_seed4/"

mses = {"train": np.load(the_dir+"train_mse.npy"), "val": np.load(the_dir+"val_mse.npy")}

loss_dict = {"G": np.load(the_dir+"G_loss.npy"), "D": np.load(the_dir+"D_loss.npy")}

grid = np.load(the_dir+"grid.npy")

pred_dict = {
    "$\hat{x}$": np.load(the_dir+"$\hat{x}$_pred.npy"),
    "$\hat{y}$": np.load(the_dir+"$\hat{y}$_pred.npy"),
    "$x$": np.load(the_dir+"$x$_pred.npy"),
    "$y$": np.load(the_dir+"$y$_pred.npy"),
}

diff_dict = {
    "$|\hat{F_1}|$": np.load(the_dir+"$|\hat{F_1}|$_diff.npy"),
    "$|\hat{F_2}|$": np.load(the_dir+"$|\hat{F_2}|$_diff.npy"),
}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=the_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/COO_run_gan_besthype_052220_seed4/

# %%
sho_dir = "/Users/dylanrandle/Downloads/SHO_run_gan_052320_seed0/"

mses = {"train": np.load(sho_dir+"train_mse.npy"), "val": np.load(sho_dir+"val_mse.npy")}

loss_dict = {"G": np.load(sho_dir+"G_loss.npy"), "D": np.load(sho_dir+"D_loss.npy")}

grid = np.load(sho_dir+"grid.npy")

pred_dict = {"$\hat{x}$": np.load(sho_dir+"$\hat{x}$_pred.npy"), "$x$": np.load(sho_dir+"$x$_pred.npy")}

diff_dict = {"$|\hat{F}|$": np.load(sho_dir+"$|\hat{F}|$_diff.npy")}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=sho_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/SHO_run_gan_052320_seed0/

# %%
exp_dir = "/Users/dylanrandle/Downloads/EXP_run_gan_053020/"

mses = {"train": np.load(exp_dir+"train_mse.npy"), "val": np.load(exp_dir+"val_mse.npy")}

loss_dict = {"G": np.load(exp_dir+"G_loss.npy"), "D": np.load(exp_dir+"D_loss.npy")}

grid = np.load(exp_dir+"grid.npy")

pred_dict = {"$\hat{x}$": np.load(exp_dir+"$\hat{x}$_pred.npy"), "$x$": np.load(exp_dir+"$x$_pred.npy")}

diff_dict = {"$|\hat{F}|$": np.load(exp_dir+"$|\hat{F}|$_diff.npy")}

# %%
plot_results(mses, loss_dict, grid, pred_dict, diff_dict=diff_dict,
    save=True, dirname=exp_dir, logloss=False, alpha=0.7)
# Out:
# Saving results to /Users/dylanrandle/Downloads/EXP_run_gan_053020/
