# %%
from denn.utils import Discriminator, Generator
from denn.nlo.gan_nlo import train_GAN_NLO_unsupervised, train_GAN_NLO_semisupervised
import torch.nn as nn

# %% [markdown]
# # Unsupervised

# %%
D = Discriminator(in_dim=2, out_dim=1,
                  n_hidden_units=32,
                  n_hidden_layers=4,
                  activation=nn.Tanh(),
                  unbounded=True,   # true for WGAN
                  residual=True)

G = Generator(in_dim=1, out_dim=1,
              n_hidden_units=32,
              n_hidden_layers=4,
              activation=nn.Tanh(), # twice diff'able activation
              output_tan=True,      # true output range should be (-1,1) if True
              residual=True)

res = train_GAN_NLO_unsupervised(G, D, d_lr=2e-4, num_epochs=10000, final_plot=True)
# Out:
# Numerical solution success: True
# Final MSE: 0.0018446407048031688
