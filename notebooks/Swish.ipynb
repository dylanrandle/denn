# %%
from pde_nn.utils import expose_results

# %% [markdown]
# ## Swish activation, $\kappa = 0.41$

# %%
expose_results('1553820917.7411568', numerical_file='data/mixlen_numerical_u180_halfk.npy')
# Out:
# hypers:
# {'dp_dx': -1.0, 'nu': 0.0055555555, 'rho': 1.0, 'k': 0.41, 'num_units': 40, 'num_layers': 2, 'batch_size': 1000, 'lr': 0.0001, 'num_epochs': 100000, 'ymin': -1, 'ymax': 1, 'weight_decay': 0, 'delta': 1, 'n': 1000, 'in_dim': 1, 'out_dim': 1, 'retau': 180.0, 'sampling': 'perturb', 'activation': 'swish'}
