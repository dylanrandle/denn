# %%
from utils import expose_results

# %% [markdown]
# ## Fixed: 100K epochs, 1k grid points

# %%
expose_results('1551333262.368149')

# %% [markdown]
# ## Fixed: 10K epochs, 1k grid points

# %%
expose_results('1551366316.362773')

# %% [markdown]
# ## Perturbed: 10K iters, 1k grid points with noise ~ $N(0, \Delta y)$

# %%
expose_results('1551367271.3275142')

# %% [markdown]
# ## Perturbed: 10K iters, 1k grid points with noise ~ $N(0, \Delta y / 3)$

# %%
expose_results('1551367883.1569438')

# %% [markdown]
# ## Geometric Grid

# %%
import numpy as np

# %%
lhs = np.geomspace(0.02, 1, num=500) - 1.02
rhs = np.flip(-lhs, axis=0)
geomgrid = np.concatenate([lhs, rhs])

# %%
import matplotlib.pyplot as plt
plt.hist(geomgrid, density=True);

# %%
expose_results('1551371072.845532')
